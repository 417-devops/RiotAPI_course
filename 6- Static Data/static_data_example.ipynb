# %%
import pandas as pd

#%% read in the champion data json, retaining only the data field
champ_data= pd.json_normalize(pd.read_json('ddragon_full_champ_data-KEYS.json').data)

# %%
#%% retain only the fields we care about
champ_data= champ_data[['id','key','tags','stats.attackrange']]
print(champ_data['tags'].head())
# Out:
# 0         [Fighter, Tank]
# 1        [Mage, Assassin]
# 2              [Assassin]
# 3    [Marksman, Assassin]
# 4         [Tank, Support]
# Name: tags, dtype: object

# %%
# we want to filter on the tags, so let's make them separate columns 
champ_data[['primary type', 'secondary type']] = champ_data['tags'].apply(lambda x: pd.Series(x) if isinstance(x, list) else pd.Series([x, None]))
print(champ_data.head())
# Out:
#         id  key                  tags  stats.attackrange primary type  \
# 0   Aatrox  266       [Fighter, Tank]              175.0      Fighter
# 1     Ahri  103      [Mage, Assassin]              550.0         Mage
# 2    Akali   84            [Assassin]              125.0     Assassin
# 3   Akshan  166  [Marksman, Assassin]              500.0     Marksman
# 4  Alistar   12       [Tank, Support]              125.0         Tank
#
#   secondary type
# 0           Tank
# 1       Assassin
# 2            NaN
# 3       Assassin
# 4        Support

# %%
#%% now get the ADCs
adc_data = champ_data[champ_data['primary type'] == 'Marksman']
adc_data
# Out:
#               id  key                  tags  stats.attackrange primary type  \
# 3         Akshan  166  [Marksman, Assassin]              500.0     Marksman
# 8       Aphelios  523            [Marksman]              550.0     Marksman
# 9           Ashe   22   [Marksman, Support]              600.0     Marksman
# 16       Caitlyn   51            [Marksman]              650.0     Marksman
# 20         Corki   42            [Marksman]              550.0     Marksman
# 23        Draven  119            [Marksman]              550.0     Marksman
# 28        Ezreal   81      [Marksman, Mage]              550.0     Marksman
# 37        Graves  104            [Marksman]              425.0     Marksman
# 48          Jhin  202      [Marksman, Mage]              550.0     Marksman
# 49          Jinx  222            [Marksman]              525.0     Marksman
# 50         Kaisa  145            [Marksman]              525.0     Marksman
# 51       Kalista  429            [Marksman]              525.0     Marksman
# 60       Kindred  203            [Marksman]              500.0     Marksman
# 62        KogMaw   96      [Marksman, Mage]              500.0     Marksman
# 68        Lucian  236            [Marksman]              500.0     Marksman
# 75   MissFortune   21            [Marksman]              550.0     Marksman
# 93         Quinn  133  [Marksman, Assassin]              525.0     Marksman
# 104       Samira  360            [Marksman]              500.0     Marksman
# 106        Senna  235   [Marksman, Support]              600.0     Marksman
# 114        Sivir   15            [Marksman]              500.0     Marksman
# 125        Teemo   17  [Marksman, Assassin]              500.0     Marksman
# 127     Tristana   18  [Marksman, Assassin]              525.0     Marksman
# 131       Twitch   29  [Marksman, Assassin]              550.0     Marksman
# 134        Varus  110      [Marksman, Mage]              575.0     Marksman
# 135        Vayne   67  [Marksman, Assassin]              550.0     Marksman
# 145        Xayah  498            [Marksman]              525.0     Marksman
# 154         Zeri  221            [Marksman]              500.0     Marksman
#
#     secondary type
# 3         Assassin
# 8              NaN
# 9          Support
# 16             NaN
# 20             NaN
# 23             NaN
# 28            Mage
# 37             NaN
# 48            Mage
# 49             NaN
# 50             NaN
# 51             NaN
# 60             NaN
# 62            Mage
# 68             NaN
# 75             NaN
# 93        Assassin
# 104            NaN
# 106        Support
# 114            NaN
# 125       Assassin
# 127       Assassin
# 131       Assassin
# 134           Mage
# 135       Assassin
# 145            NaN
# 154            NaN

# %%
# order by decreasing attack range
adc_data= adc_data.sort_values(by = 'stats.attackrange', ascending = False) #organize into leaderboard
adc_data.reset_index(drop=True, inplace=True) #reset index to match order

print(adc_data[['id','stats.attackrange']].head(3))
print('\n', adc_data[['id','stats.attackrange']].tail(3))
# Out:
#         id  stats.attackrange
# 0  Caitlyn              650.0
# 1     Ashe              600.0
# 2    Senna              600.0
#
#           id  stats.attackrange
# 24  Kindred              500.0
# 25     Zeri              500.0
# 26   Graves              425.0
